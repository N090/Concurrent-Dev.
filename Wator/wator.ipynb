# %%
import matplotlib.pyplot as plt

# Data for each test
test_data = [
    [24, 24, 27, 30, 31, 33, 35, 36, 36, 37, 38, 36, 38, 37, 37, 37, 37, 38, 37, 37, 36, 35, 34, 34, 37, 34, 32, 31, 29, 29, 31, 30, 30, 29, 31, 32, 34, 33, 33, 33, 34, 34, 36, 34, 34, 33, 32, 32, 34, 33],
    [14, 14, 15, 18, 20, 21, 25, 24, 23, 24, 26, 25, 32, 23, 25, 24, 25, 24, 25, 24, 23, 28, 23, 21, 23, 22, 21, 20, 19, 19, 20, 19, 19, 19, 20, 20, 22, 22, 21, 22, 22, 23, 25, 23, 24, 22, 20, 21, 22, 20],
    [10, 9, 11, 13, 15, 16, 18, 20, 16, 17, 19, 18, 18, 17, 19, 16, 15, 15, 15, 15, 15, 16, 15, 13, 13, 14, 15, 13, 11, 13, 12, 11, 12, 12, 11, 12, 13, 15, 13, 12, 13, 15, 15, 15, 13, 15, 16, 13, 14, 15],
    [9, 14, 9, 9, 11, 12, 13, 12, 13, 13, 14, 13, 14, 14, 13, 12, 14, 14, 14, 13, 12, 12, 12, 12, 12, 10, 10, 10, 10, 10, 11, 9, 10, 12, 11, 11, 11, 12, 11, 11, 11, 13, 12, 10, 11, 12, 10, 11, 10, 11]
]

# Calculate average, max, and min durations for each test
average_durations = [sum(data) / len(data) for data in test_data]
max_durations = [max(data) for data in test_data]
min_durations = [min(data) for data in test_data]

# Plotting the bar chart
threads = [f"Thread(s) {2**i}" for i in range(len(test_data))]
bar_width = 0.2
index = range(len(test_data))

plt.bar(index, average_durations, width=bar_width, label='Average Duration')
plt.bar([i + bar_width for i in index], max_durations, width=bar_width, label='Max Duration')
plt.bar([i + 2 * bar_width for i in index], min_durations, width=bar_width, label='Min Duration')

plt.xlabel('Threads')
plt.ylabel('Duration (ms)')
plt.title('Average, Max, and Min Durations Between Threads')
plt.xticks([i + bar_width for i in index], threads)
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each test
test_data = [
    [24, 24, 27, 30, 31, 33, 35, 36, 36, 37, 38, 36, 38, 37, 37, 37, 37, 38, 37, 37, 36, 35, 34, 34, 37, 34, 32, 31, 29, 29, 31, 30, 30, 29, 31, 32, 34, 33, 33, 33, 34, 34, 36, 34, 34, 33, 32, 32, 34, 33],
    [14, 14, 15, 18, 20, 21, 25, 24, 23, 24, 26, 25, 32, 23, 25, 24, 25, 24, 25, 24, 23, 28, 23, 21, 23, 22, 21, 20, 19, 19, 20, 19, 19, 19, 20, 20, 22, 22, 21, 22, 22, 23, 25, 23, 24, 22, 20, 21, 22, 20],
    [10, 9, 11, 13, 15, 16, 18, 20, 16, 17, 19, 18, 18, 17, 19, 16, 15, 15, 15, 15, 15, 16, 15, 13, 13, 14, 15, 13, 11, 13, 12, 11, 12, 12, 11, 12, 13, 15, 13, 12, 13, 15, 15, 15, 13, 15, 16, 13, 14, 15],
    [9, 14, 9, 9, 11, 12, 13, 12, 13, 13, 14, 13, 14, 14, 13, 12, 14, 14, 14, 13, 12, 12, 12, 12, 12, 10, 10, 10, 10, 10, 11, 9, 10, 12, 11, 11, 11, 12, 11, 11, 11, 13, 12, 10, 11, 12, 10, 11, 10, 11]
]

# Calculate max duration for each test
max_durations = [max(data) for data in test_data]

# Plotting the bar chart for Max Duration
threads = [f"Thread(s) {2**i}" for i in range(len(test_data))]
plt.bar(threads, max_durations, color='red')
plt.xlabel('Threads')
plt.ylabel('Max Duration (ms)')
plt.title('Max Duration per Thread(s)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each test
test_data = [
    [24, 24, 27, 30, 31, 33, 35, 36, 36, 37, 38, 36, 38, 37, 37, 37, 37, 38, 37, 37, 36, 35, 34, 34, 37, 34, 32, 31, 29, 29, 31, 30, 30, 29, 31, 32, 34, 33, 33, 33, 34, 34, 36, 34, 34, 33, 32, 32, 34, 33],
    [14, 14, 15, 18, 20, 21, 25, 24, 23, 24, 26, 25, 32, 23, 25, 24, 25, 24, 25, 24, 23, 28, 23, 21, 23, 22, 21, 20, 19, 19, 20, 19, 19, 19, 20, 20, 22, 22, 21, 22, 22, 23, 25, 23, 24, 22, 20, 21, 22, 20],
    [10, 9, 11, 13, 15, 16, 18, 20, 16, 17, 19, 18, 18, 17, 19, 16, 15, 15, 15, 15, 15, 16, 15, 13, 13, 14, 15, 13, 11, 13, 12, 11, 12, 12, 11, 12, 13, 15, 13, 12, 13, 15, 15, 15, 13, 15, 16, 13, 14, 15],
    [9, 14, 9, 9, 11, 12, 13, 12, 13, 13, 14, 13, 14, 14, 13, 12, 14, 14, 14, 13, 12, 12, 12, 12, 12, 10, 10, 10, 10, 10, 11, 9, 10, 12, 11, 11, 11, 12, 11, 11, 11, 13, 12, 10, 11, 12, 10, 11, 10, 11]
]

# Calculate min duration for each test
min_durations = [min(data) for data in test_data]

# Plotting the bar chart for Min Duration
threads = [f"Thread(s) {2**i}" for i in range(len(test_data))]
plt.bar(threads, min_durations, color='blue')
plt.xlabel('Threads')
plt.ylabel('Min Duration (ms)')
plt.title('Min Duration per Thread(s)')
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for each test
test_data = [
    [24, 24, 27, 30, 31, 33, 35, 36, 36, 37, 38, 36, 38, 37, 37, 37, 37, 38, 37, 37, 36, 35, 34, 34, 37, 34, 32, 31, 29, 29, 31, 30, 30, 29, 31, 32, 34, 33, 33, 33, 34, 34, 36, 34, 34, 33, 32, 32, 34, 33],
    [14, 14, 15, 18, 20, 21, 25, 24, 23, 24, 26, 25, 32, 23, 25, 24, 25, 24, 25, 24, 23, 28, 23, 21, 23, 22, 21, 20, 19, 19, 20, 19, 19, 19, 20, 20, 22, 22, 21, 22, 22, 23, 25, 23, 24, 22, 20, 21, 22, 20],
    [10, 9, 11, 13, 15, 16, 18, 20, 16, 17, 19, 18, 18, 17, 19, 16, 15, 15, 15, 15, 15, 16, 15, 13, 13, 14, 15, 13, 11, 13, 12, 11, 12, 12, 11, 12, 13, 15, 13, 12, 13, 15, 15, 15, 13, 15, 16, 13, 14, 15],
    [9, 14, 9, 9, 11, 12, 13, 12, 13, 13, 14, 13, 14, 14, 13, 12, 14, 14, 14, 13, 12, 12, 12, 12, 12, 10, 10, 10, 10, 10, 11, 9, 10, 12, 11, 11, 11, 12, 11, 11, 11, 13, 12, 10, 11, 12, 10, 11, 10, 11]
]

# Calculate average duration for each test
average_durations = [sum(data) / len(data) for data in test_data]

# Plotting the bar chart for Average Duration
threads = [f"Thread(s) {2**i}" for i in range(len(test_data))]
plt.bar(threads, average_durations, color='green')
plt.xlabel('Threads')
plt.ylabel('Average Duration (ms)')
plt.title('Average Duration per Thread(s)')
plt.show()
